# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import time

# %%
from torch.utils.data import DataLoader, Dataset

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Current device:", device)
# Out:
# Current device: cuda

# %%
class testLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, dropout=0, bidirectional=False, num_layers=1):
        super(testLSTM, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_direction = int(bidirectional) + 1
        self.rnn = nn.LSTM(input_size, hidden_size, batch_first=False, num_layers=num_layers, dropout=dropout, bidirectional=bidirectional)
        self.fc = nn.Linear(hidden_size, 1)
    
    def forward(self, input):
        output = input
        rnn_output, _ = self.rnn(output)
        output = self.fc(rnn_output)
        return output

# %%
class testNN(nn.Module):
    def __init__(self):
        super(testNN, self).__init__()
        self.fc = nn.Linear(1, 5)
        self.fc2 = nn.Linear(5, 1)
        self.act_func = nn.ReLU()
    
    def forward(self, input):
        output = self.act_func(self.fc(input))
        output = self.fc2(output)
        return output

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('data/2002.csv', encoding='euc-kr')
for y in range(2003, 2023):
    new_df = pd.read_csv('data/{}.csv'.format(y), encoding='euc-kr')
    df = pd.concat([df, new_df])
df = df.reset_index(drop=True)
df
# Out:
#          지점 지점명                일시  적설(cm)  3시간신적설(cm)
# 0        90  속초  2002-01-01 00:00     0.9         NaN
# 1        90  속초  2002-01-01 03:00     0.9         NaN
# 2        90  속초  2002-01-01 04:00     0.9         NaN
# 3        90  속초  2002-01-01 05:00     0.9         NaN
# 4        90  속초  2002-01-01 06:00     0.9         NaN
# ...     ...  ..               ...     ...         ...
# 327251  278  의성  2022-03-19 13:00     0.4         NaN
# 327252  284  거창  2022-01-19 20:00     0.2         NaN
# 327253  284  거창  2022-01-19 21:00     0.1         NaN
# 327254  284  거창  2022-03-19 11:00     0.1         NaN
# 327255  294  거제  2022-04-13 12:00    33.3         NaN
#
# [327256 rows x 5 columns]

# %%
def is_cont(df):
    point = np.array(df['지점'])
    location = np.array(df['지점명'])
    date = np.array(df['일시'])
    snow = np.array(df['적설(cm)']) * 10
    year = []
    month = []
    day = []
    hour = []
    strp = []
    mk = []
    continuous_1_hour = []
    continuous_3_hours = []
    continuous_6_hours = []

    for n, t in enumerate(date):
        t = time.strptime(t, '%Y-%m-%d %H:%M')
        strp.append(t)
        mk.append(time.mktime(t))
        year.append(t.tm_year)
        month.append(t.tm_mon)
        day.append(t.tm_mday)
        hour.append(t.tm_hour)

    # for n, k in enumerate(mk):
    #     is_1_hour = (k + 3600.0 in mk)
    #     is_3_hours = (k + 10800.0 in mk)
    #     is_6_hours = (k + 21600.0 in mk)
    #     continuous_1_hour.append(is_1_hour)
    #     continuous_3_hours.append(is_3_hours)
    #     continuous_6_hours.append(is_6_hours)
    dic = {'point': point, 'location': location, 'snow': snow, 'year': year, 'month': month, 'day': day, 'hour': hour}
    df2 = pd.DataFrame(dic)
    return df2

# %%
point_idx = list(set(df['지점']))
idx = np.array(df.groupby('지점').count()['지점명'] > 5000)
points = point_idx * idx
points_idx = []
for p in points:
    if p > 0:
        points_idx.append(p)
points_idx
# Out:
# [90,
#  95,
#  98,
#  100,
#  101,
#  102,
#  104,
#  108,
#  112,
#  114,
#  115,
#  119,
#  129,
#  131,
#  133,
#  140,
#  156,
#  165,
#  172,
#  175,
#  216,
#  232,
#  235,
#  245,
#  251]

# %%
is_filtered = []
for n, p in enumerate(df['지점']):
    if p in points_idx:
        is_filtered.append(True)
    else:
        is_filtered.append(False)

df['is_filtered'] = is_filtered
df_filtered = df[df['is_filtered']==True]
df_filtered
# Out:
#          지점  지점명                일시  적설(cm)  3시간신적설(cm)  is_filtered
# 0        90   속초  2002-01-01 00:00     0.9         NaN         True
# 1        90   속초  2002-01-01 03:00     0.9         NaN         True
# 2        90   속초  2002-01-01 04:00     0.9         NaN         True
# 3        90   속초  2002-01-01 05:00     0.9         NaN         True
# 4        90   속초  2002-01-01 06:00     0.9         NaN         True
# ...     ...  ...               ...     ...         ...          ...
# 326688  251  고창군  2022-02-20 10:00     0.8         NaN         True
# 326689  251  고창군  2022-02-20 11:00     0.3         NaN         True
# 326690  251  고창군  2022-02-23 01:00     0.5         NaN         True
# 326691  251  고창군  2022-02-23 02:00     0.4         NaN         True
# 326692  251  고창군  2022-02-23 03:00     0.2         NaN         True
#
# [205161 rows x 6 columns]

# %%
def make_lstm_by_points(lstm_by_points, hours):
    for p in points_idx:
        lstm_by_points[p] = []

    for key in lstm_by_points.keys():
        print("Training at {} point".format(key))
        net = NN().to(device)
        net_test = testNN().to(device)
        optimizer = optim.Adam(net.parameters(), lr=0.001)
        optimizer_test = optim.Adam(net_test.parameters(), lr=0.01)
        lstm_by_points[key].append(net_test)
        lstm_by_points[key].append(optimizer_test)
        df_90 = df_filtered.fillna(0)

        df_90 = df_90[df_90['지점']==key]
        df_90 = df_90[df_90['적설(cm)']>0]
        df2_90 = is_cont(df_90)
        df2_90_train = df2_90[df2_90['year'] < 2018]
        df2_90_test = df2_90[df2_90['year'] >= 2018]
        scaler = MinMaxScaler(feature_range=(0,1))
        scaler = scaler.fit((np.array(df2_90_train['snow'])).reshape(-1, 1))
        input_data = torch.tensor(scaler.transform((np.array(df2_90_train['snow'][:-hours])).reshape(-1, 1)), dtype=torch.float).reshape(-1, 1, 1).to(device)
        target_data = torch.tensor(scaler.transform((np.array(df2_90_train['snow'][hours:])).reshape(-1, 1)), dtype=torch.float).reshape(-1, 1, 1).to(device)
        input_data_test = torch.tensor(scaler.transform((np.array(df2_90_test['snow'][:-hours]).reshape(-1, 1))), dtype=torch.float).reshape(-1, 1, 1).to(device)
        target_data_test = np.array(df2_90_test['snow'][hours:]).reshape(-1, 1)
        loss_epoch = []
        rmse_val_epoch = []

        for epoch in range(2000):

            output = net(input_data)
            # output_NN = net_test(input_data.reshape(-1, 1))
            loss = criterion(output, target_data.reshape(-1, 1))
            # loss_NN = criterion(output_NN, target_data.reshape(-1, 1))
            output_test = net(input_data_test)
            output_test = scaler.inverse_transform((output_test.detach().cpu().numpy().reshape(-1, 1)))
            rmse_val = np.sqrt( np.sum( (output_test-target_data_test) ** 2 ) / len( output_test ) )


            optimizer_test.zero_grad()
            loss_NN.backward()
            optimizer_test.step()

            if (epoch + 1) % 100 == 0:
                print("Epoch {} | Loss {:.4f} | Val. RMSE {:.4f}".format(epoch+1, loss_NN.item(), rmse_val))
                loss_epoch += [loss.item()]
                rmse_val_epoch += [rmse_val]

        lstm_by_points[key].append(loss_epoch)
        lstm_by_points[key].append(rmse_val_epoch)
        lstm_by_points[key].append(scaler)
    
    return lstm_by_points

# %%
failure_prob_by_time = {}
for i in range(1, 13):
    failure_prob_by_time[i] = {}
    failure_prob_by_time[i] = make_lstm_by_points(failure_prob_by_time[i], i)
# Out:
# Training at 90 point
# Epoch 100 | Loss 0.0001 | Val. RMSE 7.4308
# Epoch 200 | Loss 0.0001 | Val. RMSE 7.4073
# Epoch 300 | Loss 0.0001 | Val. RMSE 7.4073
# Epoch 400 | Loss 0.0001 | Val. RMSE 7.4073
# Epoch 500 | Loss 0.0001 | Val. RMSE 7.4073
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [506], in <cell line: 2>()
#       2 for i in range(1, 13):
#       3     failure_prob_by_time[i] = {}
# ----> 4     failure_prob_by_time[i] = make_lstm_by_points(failure_prob_by_time[i], i)
#
# Input In [504], in make_lstm_by_points(lstm_by_points, hours)
#      27 rmse_val_epoch = []
#      29 for epoch in range(2000):
# ---> 31     output = net(input_data)
#      32     output_NN = net_test(input_data.reshape(-1, 1))
#      33     loss = criterion(output, target_data.reshape(-1, 1))
#
# File ~\anaconda3\envs\torch-1.10.1\lib\site-packages\torch\nn\modules\module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# Input In [356], in NN.forward(self, x)
#       8 def forward(self, x):
# ----> 9     x_, _ = self.lstm_1(x)
#      11     #gathering only the latent end-of-sequence for the linear layer
#      12     x_ = x_[:, -1, :]
#
# File ~\anaconda3\envs\torch-1.10.1\lib\site-packages\torch\nn\modules\module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\envs\torch-1.10.1\lib\site-packages\blitz\modules\lstm_bayesian_layer.py:249, in BayesianLSTM.forward(self, x, hidden_states, sharpen_loss)
#     246 if not self.sharpen:
#     247     sharpen_posterior = False
# --> 249 return self.forward_(x, hidden_states, sharpen_loss)
#
# File ~\anaconda3\envs\torch-1.10.1\lib\site-packages\blitz\modules\lstm_bayesian_layer.py:138, in BayesianLSTM.forward_(self, x, hidden_states, sharpen_loss)
#     135     weight_ih, weight_hh, bias = self.sharpen_posterior(loss=sharpen_loss, input_shape=x.shape)
#     137 else:
# --> 138     weight_ih, weight_hh, bias = self.sample_weights()
#     140 #Assumes x is of shape (batch, sequence, feature)
#     141 bs, seq_sz, _ = x.size()
#
# File ~\anaconda3\envs\torch-1.10.1\lib\site-packages\blitz\modules\lstm_bayesian_layer.py:106, in BayesianLSTM.sample_weights(self)
#     103 #gather weights variational posterior and prior likelihoods
#     104 self.log_variational_posterior = self.weight_hh_sampler.log_posterior() + b_log_posterior + self.weight_ih_sampler.log_posterior()
# --> 106 self.log_prior = self.weight_ih_prior_dist.log_prior(weight_ih) + b_log_prior + self.weight_hh_prior_dist.log_prior(weight_hh)
#     109 self.ff_parameters = [weight_ih, weight_hh, bias]
#     110 return weight_ih, weight_hh, bias
#
# File ~\anaconda3\envs\torch-1.10.1\lib\site-packages\blitz\modules\weight_sampler.py:87, in PriorWeightDistribution.log_prior(self, w)
#      84 prob_n1 = torch.exp(self.dist1.log_prob(w))
#      86 if self.dist2 is not None:
# ---> 87     prob_n2 = torch.exp(self.dist2.log_prob(w))
#      88 if self.dist2 is None:
#      89     prob_n2 = 0
#
# File ~\anaconda3\envs\torch-1.10.1\lib\site-packages\torch\distributions\normal.py:73, in Normal.log_prob(self, value)
#      71 def log_prob(self, value):
#      72     if self._validate_args:
# ---> 73         self._validate_sample(value)
#      74     # compute the variance
#      75     var = (self.scale ** 2)
#
# File ~\anaconda3\envs\torch-1.10.1\lib\site-packages\torch\distributions\distribution.py:287, in Distribution._validate_sample(self, value)
#     285 assert support is not None
#     286 valid = support.check(value)
# --> 287 if not valid.all():
#     288     raise ValueError(
#     289         "Expected value argument "
#     290         f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)
#     293         f"but found invalid values:\n{value}"
#     294     )
#
# KeyboardInterrupt:

# %%
hours = 1
lstm_by_points_1 = {}
lstm_by_points = make_lstm_by_points(lstm_by_points_1, hours)
# Out:
# Training at 90 point
# Epoch 100 | Loss 0.0002 | Val. RMSE 7.4603
# Epoch 200 | Loss 0.0001 | Val. RMSE 7.4139
# Epoch 300 | Loss 0.0001 | Val. RMSE 7.4078
# Epoch 400 | Loss 0.0001 | Val. RMSE 7.4075
# Epoch 500 | Loss 0.0001 | Val. RMSE 7.4074
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [503], in <cell line: 3>()
#       1 hours = 1
#       2 lstm_by_points_1 = {}
# ----> 3 lstm_by_points = make_lstm_by_points(lstm_by_points_1, hours)
#
# Input In [501], in make_lstm_by_points(lstm_by_points, hours)
#      27 rmse_val_epoch = []
#      29 for epoch in range(2000):
# ---> 31     output = net(input_data)
#      32     output_NN = net_test(input_data.reshape(-1, 1))
#      33     loss = criterion(output, target_data.reshape(-1, 1))
#
# File ~\anaconda3\envs\torch-1.10.1\lib\site-packages\torch\nn\modules\module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# Input In [356], in NN.forward(self, x)
#       8 def forward(self, x):
# ----> 9     x_, _ = self.lstm_1(x)
#      11     #gathering only the latent end-of-sequence for the linear layer
#      12     x_ = x_[:, -1, :]
#
# File ~\anaconda3\envs\torch-1.10.1\lib\site-packages\torch\nn\modules\module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\envs\torch-1.10.1\lib\site-packages\blitz\modules\lstm_bayesian_layer.py:249, in BayesianLSTM.forward(self, x, hidden_states, sharpen_loss)
#     246 if not self.sharpen:
#     247     sharpen_posterior = False
# --> 249 return self.forward_(x, hidden_states, sharpen_loss)
#
# File ~\anaconda3\envs\torch-1.10.1\lib\site-packages\blitz\modules\lstm_bayesian_layer.py:138, in BayesianLSTM.forward_(self, x, hidden_states, sharpen_loss)
#     135     weight_ih, weight_hh, bias = self.sharpen_posterior(loss=sharpen_loss, input_shape=x.shape)
#     137 else:
# --> 138     weight_ih, weight_hh, bias = self.sample_weights()
#     140 #Assumes x is of shape (batch, sequence, feature)
#     141 bs, seq_sz, _ = x.size()
#
# File ~\anaconda3\envs\torch-1.10.1\lib\site-packages\blitz\modules\lstm_bayesian_layer.py:94, in BayesianLSTM.sample_weights(self)
#      92     b = self.bias_sampler.sample()
#      93     b_log_posterior = self.bias_sampler.log_posterior()
# ---> 94     b_log_prior = self.bias_prior_dist.log_prior(b)
#      96 else:
#      97     b = None
#
# File ~\anaconda3\envs\torch-1.10.1\lib\site-packages\blitz\modules\weight_sampler.py:84, in PriorWeightDistribution.log_prior(self, w)
#      77 def log_prior(self, w):
#      78     """
#      79     Calculates the log_likelihood for each of the weights sampled relative to a prior distribution as a part of the complexity cost
#      80
#      81     returns:
#      82         torch.tensor with shape []
#      83     """
# ---> 84     prob_n1 = torch.exp(self.dist1.log_prob(w))
#      86     if self.dist2 is not None:
#      87         prob_n2 = torch.exp(self.dist2.log_prob(w))
#
# File ~\anaconda3\envs\torch-1.10.1\lib\site-packages\torch\distributions\normal.py:73, in Normal.log_prob(self, value)
#      71 def log_prob(self, value):
#      72     if self._validate_args:
# ---> 73         self._validate_sample(value)
#      74     # compute the variance
#      75     var = (self.scale ** 2)
#
# File ~\anaconda3\envs\torch-1.10.1\lib\site-packages\torch\distributions\distribution.py:286, in Distribution._validate_sample(self, value)
#     284     return
#     285 assert support is not None
# --> 286 valid = support.check(value)
#     287 if not valid.all():
#     288     raise ValueError(
#     289         "Expected value argument "
#     290         f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)
#     293         f"but found invalid values:\n{value}"
#     294     )
#
# File ~\anaconda3\envs\torch-1.10.1\lib\site-packages\torch\distributions\constraints.py:301, in _Real.check(self, value)
#     300 def check(self, value):
# --> 301     return value == value
#
# KeyboardInterrupt:

# %%
hours = 6
lstm_by_points_6 = {}
lstm_by_points = make_lstm_by_points(lstm_by_points_6, hours)

# %%
aa = 0
for key in lstm_by_points_1.keys():
    aa += lstm_by_points[key][3][-1]
aa / len(lstm_by_points_1.keys())
# Out:
# 10.1860385730419

# %%
def get_transformed_tensor(a:float, scaler):
    b = scaler.transform(np.array([a], dtype=np.float32).reshape(-1, 1))
    b = torch.tensor(b).to(device).reshape(-1, 1, 1)
    return b

# %%
def get_inverse_float(a, scaler):
    b = scaler.inverse_transform(a.detach().cpu().numpy())
    return b

# %%
lstm_by_points

# %%
heights = 180
fail_prob_points = {}
for key in lstm_by_points_1.keys():
    b = get_transformed_tensor(heights, lstm_by_points_1[key][4])
    ss = []
    for _ in range(100):
        a = get_inverse_float(lstm_by_points_1[key][0](b), lstm_by_points_1[key][4])
        if a >= 190:
            ss += [1]
        else:
            ss += [0]
        fail_prob_points[key] = np.mean(ss)
fail_prob_points
# Out:
# {90: 0.14,
#  95: 0.04,
#  98: 0.17,
#  100: 0.37,
#  101: 0.01,
#  102: 0.01,
#  104: 0.3,
#  108: 0.06,
#  112: 0.04,
#  114: 0.0,
#  115: 0.36,
#  119: 0.0,
#  129: 0.04,
#  131: 0.11,
#  133: 0.09,
#  140: 0.0,
#  156: 0.22,
#  165: 0.12,
#  172: 0.17,
#  175: 0.02,
#  216: 0.44,
#  232: 0.01,
#  235: 0.08,
#  245: 0.26,
#  251: 0.11}

# %%
key = 115

# %%
df_90 = df_filtered.fillna(0)

df_90 = df_90[df_90['지점']==key]
df_90 = df_90[df_90['적설(cm)']>0]
df2_90 = is_cont(df_90)
df2_90_train = df2_90[df2_90['year'] < 2018]
df2_90_test = df2_90[df2_90['year'] >= 2018]
scaler = MinMaxScaler(feature_range=(0,1))
scaler = scaler.fit(np.array(df2_90_train['snow']).reshape(-1, 1))

input_data_test = torch.tensor(scaler.transform(np.array(df2_90_test['snow'][:-hours]).reshape(-1, 1)), dtype=torch.float).reshape(-1, 1, 1).to(device)
target_data_test = torch.tensor(scaler.transform(np.array(df2_90_test['snow'][hours:]).reshape(-1, 1)), dtype=torch.float).reshape(-1, 1, 1).to(device)

net = lstm_by_points_12[key][0]
data = net(input_data_test)

output_test = np.array([scaler.inverse_transform(data.detach().cpu().numpy().reshape(-1, 1)) for i in range(5)])
output_test = np.where(output_test < 0, 0, output_test)
target_test = np.array(df2_90_test['snow'][hours:])
pred_mean, upper_bound, lower_bound = get_confidence_intervals(output_test, 1.96)
x_idx = np.arange(len(upper_bound))
plt.figure(figsize=(16, 8))
plt.plot(x_idx, pred_mean, 'r--', linewidth=2, label='mean pred')
plt.plot(x_idx, target_test, fillstyle='none', marker='o', color='k', label='target', linestyle='none')
# plt.plot(x_idx, lower_bound, 'b--', linewidth=2, label='mean pred')
# plt.plot(x_idx, upper_bound, 'g--', linewidth=2, label='mean pred')
plt.fill_between(x=x_idx, y1=upper_bound.flatten(), y2=lower_bound.flatten(), facecolor='green', label='confidence interval', alpha=1)
plt.legend()
plt.title(key)
# Out:
# Text(0.5, 1.0, '115')

# %%
print(df2_90_test)
# Out:
#       point location  snow  year  month  day  hour
# 4115    251      고창군   4.0  2018      1    9     3
# 4116    251      고창군   5.0  2018      1    9     4
# 4117    251      고창군   4.0  2018      1    9     5
# 4118    251      고창군   7.0  2018      1    9     6
# 4119    251      고창군   9.0  2018      1    9     7
# ...     ...      ...   ...   ...    ...  ...   ...
# 5736    251      고창군   8.0  2022      2   20    10
# 5737    251      고창군   3.0  2022      2   20    11
# 5738    251      고창군   5.0  2022      2   23     1
# 5739    251      고창군   4.0  2022      2   23     2
# 5740    251      고창군   2.0  2022      2   23     3
#
# [1626 rows x 7 columns]

# %%
plt.figure(figsize=(8, 8))
plt.scatter(pred_mean.flatten(), target_test)
plt.plot([0, np.max(pred_mean)], [0, np.max(pred_mean)], 'r-')
plt.title(key)
# Out:
# Text(0.5, 1.0, '251')

# %%
np.sqrt( np.sum( (pred_mean.flatten() - target_test) ** 2 ) / len(target_test) )
# Out:
# 25.01210942261154

# %% [markdown]
# ## Single Point

# %%
df_90 = df_filtered.fillna(0)

df_90 = df_90[df_90['지점명']=='동두천']
df_90 = df_90[df_90['적설(cm)']>0]
df2_90 = is_cont(df_90)

# %%
df2_90_train = df2_90[df2_90['year'] < 2018]
df2_90_test = df2_90[df2_90['year'] >= 2018]
scaler = MinMaxScaler(feature_range=(0,1))
scaler = scaler.fit((np.array(df2_90_train['snow'])).reshape(-1, 1))

# %%
df2_90_test
# Out:
#       point location  snow  year  month  day  hour
# 4478     98      동두천   7.0  2018      1    8    20
# 4479     98      동두천   7.0  2018      1    8    21
# 4480     98      동두천  11.0  2018      1    8    22
# 4481     98      동두천  10.0  2018      1    8    23
# 4482     98      동두천  10.0  2018      1    9     0
# ...     ...      ...   ...   ...    ...  ...   ...
# 5829     98      동두천   6.0  2022      2    3    17
# 5830     98      동두천   1.0  2022      2    3    18
# 5831     98      동두천   1.0  2022      2    3    19
# 5832     98      동두천   1.0  2022      2    3    20
# 5833     98      동두천   1.0  2022      2    3    21
#
# [1356 rows x 7 columns]

# %%
hours = 6

# %%
input_data = torch.tensor(scaler.transform((np.array(df2_90_train['snow'][:-hours])).reshape(-1, 1)), dtype=torch.float).reshape(-1, 1, 1).to(device)
target_data = torch.tensor(scaler.transform((np.array(df2_90_train['snow'][hours:]).reshape(-1, 1))), dtype=torch.float).reshape(-1, 1, 1).to(device)

# %% [markdown]
# ## Standard LSTM

# %%
class CustomDataset(Dataset):
    def __init__(self, data, target, transform=None, target_transform=None):
        self.data = data
        self.target = target

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.target[idx]

# %%
lstm = testLSTM(1, 10, 0.0, False, num_layers=2).to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(lstm.parameters(), lr=0.01)
train_dataset = CustomDataset(input_data, target_data)
train_dataloader = DataLoader(train_dataset, batch_size=len(train_dataset), shuffle=False)

# %%
for epoch in range(2000):
    loss_epoch = []
    

        
    output = lstm(input_data)
    loss = criterion(output, target_data)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    loss_epoch += [loss.item()]
    
    if (epoch + 1) % 100 == 0:
            print("Epoch {} | Loss {:.4f}".format(epoch+1, np.mean(loss_epoch)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [329], in <cell line: 1>()
#       1 for epoch in range(2000):
#       2     loss_epoch = []
# ----> 6     output = lstm(input_data)
#       7     loss = criterion(output, target_data)
#       9     optimizer.zero_grad()
#
# File ~\anaconda3\envs\torch-1.10.1\lib\site-packages\torch\nn\modules\module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# Input In [4], in testLSTM.forward(self, input)
#      11 def forward(self, input):
#      12     output = input
# ---> 13     rnn_output, _ = self.rnn(output)
#      14     output = self.fc(rnn_output)
#      15     return output
#
# File ~\anaconda3\envs\torch-1.10.1\lib\site-packages\torch\nn\modules\module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\envs\torch-1.10.1\lib\site-packages\torch\nn\modules\rnn.py:691, in LSTM.forward(self, input, hx)
#     689 self.check_forward_args(input, hx, batch_sizes)
#     690 if batch_sizes is None:
# --> 691     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     692                       self.dropout, self.training, self.bidirectional, self.batch_first)
#     693 else:
#     694     result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#     695                       self.num_layers, self.dropout, self.training, self.bidirectional)
#
# KeyboardInterrupt:

# %%
input_data_test = torch.tensor(scaler.transform(np.array(df2_90_test['snow'][:-hours]).reshape(-1, 1)), dtype=torch.float).reshape(-1, 1, 1).to(device)
target_data_test = torch.tensor(scaler.transform(np.array(df2_90_test['snow'][hours:]).reshape(-1, 1)), dtype=torch.float).reshape(-1, 1, 1).to(device)

# %%
output_test = scaler.inverse_transform(lstm(input_data_test).detach().cpu().numpy().reshape(-1, 1))
output_test = np.where(output_test < 0, 0, output_test)
target_test = np.array(df2_90_test['snow'][hours:])

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16, 8))
plt.plot(output_test, 'r.', label='pred')
plt.plot(target_test, 'k.', label='target')
plt.legend()

# %%
np.sqrt(np.sum((output_test.flatten() - target_test) ** 2) / np.sum(output_test.flatten() ** 2))
# Out:
# 0.5813474833050273

# %%
np.sqrt(np.sum((output_test.flatten() - target_test) ** 2) / len(target_test))
# Out:
# 11.688903326043922

# %%
plt.figure(figsize=(8, 8))
plt.scatter(output_test, target_test)
plt.plot([0, np.max(output_test)], [0, np.max(output_test)], 'r-')

# %% [markdown]
# ## Bayesian LSTM

# %%
from blitz.modules import BayesianLSTM
from blitz.utils import variational_estimator

# %%
@variational_estimator
class NN(nn.Module):
    def __init__(self):
        super(NN, self).__init__()
        self.lstm_1 = BayesianLSTM(1, 10, prior_sigma_1=1, prior_pi=1, posterior_rho_init=-3.0)
        self.linear = nn.Linear(10, 1)
            
    def forward(self, x):
        x_, _ = self.lstm_1(x)
        
        #gathering only the latent end-of-sequence for the linear layer
        x_ = x_[:, -1, :]
        x_ = self.linear(x_)
        return x_

# %%
net = NN().to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)

# %%
for epoch in range(2000):
    loss_epoch = []
    output = net(input_data)
    loss = criterion(output, target_data.reshape(-1, 1))

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    loss_epoch += [loss.item()]
    
    if (epoch + 1) % 100 == 0:
            print("Epoch {} | Loss {:.4f}".format(epoch+1, np.mean(loss_epoch)))
# Out:
# Epoch 100 | Loss 0.0330
# Epoch 200 | Loss 0.0271
# Epoch 300 | Loss 0.0153
# Epoch 400 | Loss 0.0088
# Epoch 500 | Loss 0.0077
# Epoch 600 | Loss 0.0069
# Epoch 700 | Loss 0.0072
# Epoch 800 | Loss 0.0092
# Epoch 900 | Loss 0.0069
# Epoch 1000 | Loss 0.0073
# Epoch 1100 | Loss 0.0076
# Epoch 1200 | Loss 0.0069
# Epoch 1300 | Loss 0.0072
# Epoch 1400 | Loss 0.0068
# Epoch 1500 | Loss 0.0074
# Epoch 1600 | Loss 0.0068
# Epoch 1700 | Loss 0.0069
# Epoch 1800 | Loss 0.0068
# Epoch 1900 | Loss 0.0071
# Epoch 2000 | Loss 0.0068

# %%
def get_confidence_intervals(preds_test, ci_multiplier):
    pred_mean = np.mean(preds_test, axis=0)
    pred_std = np.std(preds_test, axis=0)
    upper_bound = pred_mean + (pred_std * ci_multiplier)
    lower_bound = pred_mean - (pred_std * ci_multiplier)
    return pred_mean, upper_bound, lower_bound

# %%
input_data_test = torch.tensor(scaler.transform((np.array(df2_90_test['snow'][:-hours])).reshape(-1, 1)), dtype=torch.float).reshape(-1, 1, 1).to(device)
target_data_test = torch.tensor(scaler.transform(np.array(df2_90_test['snow'][hours:]).reshape(-1, 1)), dtype=torch.float).reshape(-1, 1, 1).to(device)

data = net(input_data_test)

output_test = np.array([scaler.inverse_transform(data.detach().cpu().numpy().reshape(-1, 1)) for i in range(5)])
output_test = np.where(output_test < 0, 0, output_test)
print(output_test.shape)
target_test = np.array(df2_90_test['snow'][hours:])
pred_mean, upper_bound, lower_bound = get_confidence_intervals(output_test, 1.96)
# Out:
# (5, 1350, 1)

# %%
plt.figure(figsize=(32, 16))
x_idx = np.arange(len(upper_bound))
plt.plot(pred_mean, 'r--', linewidth=2, label='mean pred')
plt.plot(target_test, fillstyle='none', marker='o', color='k', label='target', linestyle='none')
plt.fill_between(x=x_idx, y1=upper_bound.flatten(), y2=lower_bound.flatten(), facecolor='green', label='confidence interval', alpha=0.5)
plt.legend()

# %%
np.sqrt(np.sum((pred_mean.flatten() - target_test) ** 2) / np.sum(pred_mean.flatten() ** 2))
# Out:
# 0.469172400588319

# %%
np.sqrt(np.sum((pred_mean.flatten() - target_test) ** 2) / len(target_test))
# Out:
# 14.187743168317322

# %%
plt.figure(figsize=(8, 8))

plt.scatter(pred_mean.flatten(), target_test)

# %%
test = get_transformed_tensor(20, scaler)

# %%
get_inverse_float(net(test), scaler)
# Out:
# array([[20.200212]], dtype=float32)
