# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
import time
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('data/2002.csv', encoding='euc-kr')

# %%
for y in range(2003, 2023):
    new_df = pd.read_csv('data/{}.csv'.format(y), encoding='euc-kr')
    df = pd.concat([df, new_df])

# %%
df = df.reset_index(drop=True)

# %%
df.groupby('지점명').count()
# Out:
#        지점    일시  적설(cm)  3시간신적설(cm)
# 지점명
# 강릉   2944  2944    2941         251
# 강진군  1320  1320    1318         116
# 강화   1639  1639    1637         117
# 거제    139   139     137          26
# 거창   2909  2909    2900         303
# ..    ...   ...     ...         ...
# 합천    345   345     345          57
# 해남   1123  1123    1117         247
# 홍성   1234  1234    1218         241
# 홍천   2299  2299    2292         219
# 흑산도  2905  2905    2880         672
#
# [99 rows x 4 columns]

# %%
point_idx = list(set(df['지점']))
idx = np.array(df.groupby('지점').count()['지점명'] > 5000)
points = point_idx * idx
points_idx = []
for p in points:
    if p > 0:
        points_idx.append(p)
points_idx
# Out:
# [90,
#  95,
#  98,
#  100,
#  101,
#  102,
#  104,
#  108,
#  112,
#  114,
#  115,
#  119,
#  129,
#  131,
#  133,
#  140,
#  156,
#  165,
#  172,
#  175,
#  216,
#  232,
#  235,
#  245,
#  251]

# %%
time.mktime(time.strptime(df['일시'][1], '%Y-%m-%d %H:%M')) - time.mktime(time.strptime(df['일시'][0], '%Y-%m-%d %H:%M'))
# Out:
# 10800.0

# %%
def is_cont(df):
    point = np.array(df['지점'])
    location = np.array(df['지점명'])
    date = np.array(df['일시'])
    snow = np.array(df['적설(cm)']) * 10
    year = []
    month = []
    day = []
    hour = []
    strp = []
    mk = []
    continuous_1_hour = []
    continuous_3_hours = []
    continuous_6_hours = []

    for n, t in enumerate(date):
        t = time.strptime(t, '%Y-%m-%d %H:%M')
        strp.append(t)
        mk.append(time.mktime(t))
        year.append(t.tm_year)
        month.append(t.tm_mon)
        day.append(t.tm_mday)
        hour.append(t.tm_hour)

    for n, k in enumerate(mk):
        is_1_hour = (k + 3600.0 in mk)
        is_3_hours = (k + 10800.0 in mk)
        is_6_hours = (k + 21600.0 in mk)
        continuous_1_hour.append(is_1_hour)
        continuous_3_hours.append(is_3_hours)
        continuous_6_hours.append(is_6_hours)
    dic = {'point': point, 'location': location, 'snow': snow, 'year': year, 'month': month, 'day': day, 'hour': hour, 'con_1h': continuous_1_hour, 'con_3h': continuous_3_hours, 'con_6h': continuous_6_hours}
    df2 = pd.DataFrame(dic)
    return df2

# %%
hours = 1
n_clusters = 20

# %%
test = np.array(df2_90_train['snow'])
test
input_data = test[:-10]
target_data = test[10:]
plt.scatter(input_data, target_data)
plt.plot([0, 400], [0, 400], 'r-')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 test = np.array(df2_90_train['snow'])
#       2 test
#       3 input_data = test[:-10]
#
# NameError: name 'df2_90_train' is not defined

# %%
train_by_points_times = {}

# %%
for hours in range(1, 12):
    train_by_points_times[hours] = {}
    print("Start at ", hours)
    for key in points_idx:
        train_by_points_times[hours][key] = []
        df_90 = df[df['지점']==key].fillna(0)
        df_90 = df_90[df_90['적설(cm)']>0]
        df2_90 = is_cont(df_90)
        df2_90_train = df2_90[df2_90['year'] < 2018]
        df2_90_test = df2_90[df2_90['year'] >= 2018]
        df2_90_train, minmax = make_cluster_in_order(df2_90_train, n_clusters)
        markov = np.zeros((n_clusters, n_clusters))
        for n, cl in enumerate(df2_90_train['cluster']):
            if n == len(df2_90_train['cluster'])-6:
                break
            markov[cl][df2_90_train['cluster'][n+1]] += 1
        markov_prob = np.zeros(markov.shape)
        for n, row in enumerate(markov):
            row /= np.sum(row)
            markov_prob[n] = row
        for i in range(hours - 1):
            markov_prob = markov_prob @ markov_prob
        markov_cum = np.zeros(markov.shape)
        for n, row in enumerate(markov_prob):
            for m in range(len(row)):
                markov_cum[n][m] = np.sum(row[:m+1])
        df2_90_test = make_cluster_test_data(df2_90_test, minmax)
        pred_snow_ = []
        for i in range(10):
            pred_cluster = [999] * hours
            for n, cl in enumerate(df2_90_test['cluster']):
                p = np.random.rand()
                row = markov_cum[cl]
                for k, r in enumerate(row):
                    if p < r:
                        pred_cluster.append(k)
                        break
            pred_cluster = pred_cluster[:-hours]
            df2_90_test['pred_cluster'] = pred_cluster
            pred_snow = [0] * hours
            for n, cl in enumerate(df2_90_test['pred_cluster'][hours:]):
                a, b, _ = minmax[cl]
                pred_sn = np.random.uniform(a, b, 1)[0]
                pred_snow.append(pred_sn)
            pred_snow_.append(pred_snow)
        pred_snow_ = np.array(pred_snow_)
        mean = np.mean(pred_snow_, axis=0)
        mean_95_ci = 1.96 * np.std(pred_snow_, axis=0) / np.sqrt(10)
        train_by_points_times[hours][key].append(mean)
        train_by_points_times[hours][key].append(mean - mean_95_ci)
        train_by_points_times[hours][key].append(mean + mean_95_ci)
        # df2_90_test['pred_snow_mean'] = mean
        # df2_90_test['pred_snow_low_int'] = mean - mean_95_ci
        # df2_90_test['pred_snow_high_int'] = mean + mean_95_ci
        # snow_test = df2_90_test['snow'][(df2_90_test[(df2_90_test['con_6h']==True)].index + hours)[:-hours]]
        # pred_snow_test = df2_90_test['pred_snow_mean'][(df2_90_test[(df2_90_test['con_6h']==True)].index + hours)[:-hours]]
        # pred_snow_low_int = df2_90_test['pred_snow_low_int'][(df2_90_test[(df2_90_test['con_6h']==True)].index + hours)[:-hours]]
        # pred_snow_high_int = df2_90_test['pred_snow_high_int'][(df2_90_test[(df2_90_test['con_6h']==True)].index + hours)[:-hours]]
        snow_test = df2_90_test['snow'][:-hours]
        pred_snow_test = df2_90_test['pred_snow_mean'][:-hours]
        pred_snow_low_int = df2_90_test['pred_snow_low_int'][:-hours]
        pred_snow_high_int = df2_90_test['pred_snow_high_int'][:-hours]
        rmse = np.sqrt(np.sum((snow_test - pred_snow_test) ** 2) / len(pred_snow_test))
        train_by_points_times[hours][key] = []
        train_by_points_times[hours][key].append(rmse)
# Out:
# Start at  1
# C:\Users\fembem\anaconda3\envs\torch-1.10.1\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=27.
#   warnings.warn(
# C:\Users\fembem\AppData\Local\Temp\ipykernel_22912\1207035815.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cluster']=clusters.labels_
# C:\Users\fembem\AppData\Local\Temp\ipykernel_22912\1207035815.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cluster'] = cluster_in_order
# C:\Users\fembem\AppData\Local\Temp\ipykernel_22912\3962409001.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cluster'] = cluster_test
# C:\Users\fembem\AppData\Local\Temp\ipykernel_22912\1867376019.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_90_test['pred_cluster'] = pred_cluster
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
#      46 mean = np.mean(pred_snow_, axis=0)
#      47 mean_95_ci = 1.96 * np.std(pred_snow_, axis=0) / np.sqrt(10)
# ---> 48 train_by_points_times[hours][key].append(mean)
#      49 train_by_points_times[hours][key].append(mean - mean_95_ci)
#      50 train_by_points_times[hours][key].append(mean + mean_95_ci)
#
# KeyError: 90

# %%
train_by_points_times

# %%
np.mean(list(train_by_points.values()))
# Out:
# 52.10975025735624

# %%
df_90 = df[df['지점']==98].fillna(0)
df_90 = df_90[df_90['적설(cm)']>0]

# %%
df2_90 = is_cont(df_90)

# %%
df2_90
# Out:
#       point location  snow  year  month  day  hour  con_1h  con_3h  con_6h
# 0        98      동두천   2.0  2012      1   25     0    True    True   False
# 1        98      동두천   2.0  2012      1   25     1    True   False   False
# 2        98      동두천   2.0  2012      1   25     2    True   False   False
# 3        98      동두천   2.0  2012      1   25     3   False   False   False
# 4        98      동두천   1.0  2012      1   26     5    True    True   False
# ...     ...      ...   ...   ...    ...  ...   ...     ...     ...     ...
# 2262     98      동두천   6.0  2022      2    3    17    True    True   False
# 2263     98      동두천   1.0  2022      2    3    18    True    True   False
# 2264     98      동두천   1.0  2022      2    3    19    True   False   False
# 2265     98      동두천   1.0  2022      2    3    20    True   False   False
# 2266     98      동두천   1.0  2022      2    3    21   False   False   False
#
# [2267 rows x 10 columns]

# %%
df2_90_train = df2_90[df2_90['year'] < 2018]
# df2_90_train = df[df['year'] < 2019]
df2_90_test = df2_90[df2_90['year'] >= 2018]

# %%
df2_90_test
# Out:
#       point location  snow  year  month  day  hour  con_1h  con_3h  con_6h
# 911      98      동두천   7.0  2018      1    8    20    True    True    True
# 912      98      동두천   7.0  2018      1    8    21    True    True    True
# 913      98      동두천  11.0  2018      1    8    22    True    True    True
# 914      98      동두천  10.0  2018      1    8    23    True    True    True
# 915      98      동두천  10.0  2018      1    9     0    True    True    True
# ...     ...      ...   ...   ...    ...  ...   ...     ...     ...     ...
# 2262     98      동두천   6.0  2022      2    3    17    True    True   False
# 2263     98      동두천   1.0  2022      2    3    18    True    True   False
# 2264     98      동두천   1.0  2022      2    3    19    True   False   False
# 2265     98      동두천   1.0  2022      2    3    20    True   False   False
# 2266     98      동두천   1.0  2022      2    3    21   False   False   False
#
# [1356 rows x 10 columns]

# %%
def make_cluster_in_order(df, n_clusters):
    snow = np.log(np.array(df['snow'])).reshape(-1, 1)
    kmeans = KMeans(n_clusters=n_clusters)
    clusters = kmeans.fit(snow)
    df['cluster']=clusters.labels_
    minmax = []

    dtype = [('min', float), ('max', float), ('idx', int)]
    for i in set(df['cluster']):
        cc = df[df['cluster'] == i]
        minmax.append((cc['snow'].min(), cc['snow'].max(), i))

    # minmax = np.sort(minmax, axis=0)
    minmax = np.array(minmax, dtype=dtype)
    minmax = np.sort(minmax, axis=0, order='min')
    
    cluster_in_order = []
    for n, sn in enumerate(df['snow']):
        for k, m in enumerate(minmax):
            if m[0] <= sn <= m[1]:
                cluster_in_order.append(k)
    df['cluster'] = cluster_in_order
    
    
    return df, minmax

# %%
def make_cluster_test_data(df, minmax):
    cluster_test = []
    snow = (np.array(df['snow']))
    for n, sn in enumerate(df['snow']):
        for k, m in enumerate(minmax):
            if k == len(minmax) - 1:
                cluster_test.append(k)
                break
            elif m[0] <= sn < minmax[k+1][0]:
                cluster_test.append(k)
                break
    df['cluster'] = cluster_test
    
    return df

# %%
df2_90_train, minmax = make_cluster_in_order(df2_90_train)
df2_90_train
print(minmax)
# Out:
# [( 1.,   1., 4) ( 2.,   3., 9) ( 4.,   5., 1) ( 7.,  11., 8)
#  (12.,  17., 3) (18.,  26., 7) (29.,  38., 0) (39.,  54., 5)
#  (55.,  75., 2) (80., 130., 6)]
# C:\Users\fembem\anaconda3\envs\torch-1.10.1\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\fembem\AppData\Local\Temp\ipykernel_4072\471947950.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cluster']=clusters.labels_
# C:\Users\fembem\AppData\Local\Temp\ipykernel_4072\471947950.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cluster'] = cluster_in_order

# %%
markov = np.zeros((10, 10))

# %%
for n, cl in enumerate(df2_90_train['cluster']):
    if n == len(df2_90_train['cluster'])-1:
        break
    markov[cl][df2_90_train['cluster'][n+1]] += 1

# %%
markov_prob = np.zeros(markov.shape)
for n, row in enumerate(markov):
    row /= np.sum(row)
    markov_prob[n] = row

# %%
hours = 6

# %%
for i in range(hours - 1):
    markov_prob = markov_prob @ markov_prob

# %%
markov_cum = np.zeros(markov.shape)
for n, row in enumerate(markov_prob):
    for m in range(len(row)):
        markov_cum[n][m] = np.sum(row[:m+1])

# %%
markov_cum
# Out:
# array([[0.01367147, 0.02416298, 0.16370239, 0.3724524 , 0.53136221,
#         0.67126353, 0.73575409, 0.93738356, 0.98572647, 1.        ],
#        [0.01379256, 0.02439614, 0.16551223, 0.37637858, 0.53661225,
#         0.67702292, 0.74145335, 0.93958301, 0.98640403, 1.        ],
#        [0.01386957, 0.02454538, 0.16669764, 0.37898438, 0.54015422,
#         0.68111475, 0.74555423, 0.94127313, 0.98695344, 1.        ],
#        [0.01382943, 0.02446914, 0.16611027, 0.37774031, 0.53852898,
#         0.67937607, 0.74383357, 0.94063457, 0.98676413, 1.        ],
#        [0.01294371, 0.02273467, 0.15227394, 0.34667577, 0.49546352,
#         0.62858891, 0.69282989, 0.9180823 , 0.97890622, 1.        ],
#        [0.01302041, 0.02290149, 0.15381403, 0.35071183, 0.50187231,
#         0.63796487, 0.70260447, 0.92378127, 0.98127489, 1.        ],
#        [0.01144714, 0.01981258, 0.12912484, 0.29503281, 0.42436555,
#         0.54611683, 0.61032742, 0.88262871, 0.96683569, 1.        ],
#        [0.00698446, 0.01107248, 0.05950396, 0.13687943, 0.20243935,
#         0.27896958, 0.34017293, 0.74826446, 0.91460799, 1.        ],
#        [0.00508512, 0.0077968 , 0.03853064, 0.08877531, 0.13283071,
#         0.18837533, 0.23974586, 0.60437276, 0.82250871, 1.        ],
#        [0.00291341, 0.00420981, 0.01753552, 0.04042098, 0.06189803,
#         0.09293564, 0.12955857, 0.40711728, 0.67450675, 1.        ]])

# %%
df2_90_test = make_cluster_test_data(df2_90_test, minmax)
# Out:
# C:\Users\fembem\AppData\Local\Temp\ipykernel_4072\3962409001.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cluster'] = cluster_test

# %%
df2_90_test.groupby('cluster').count()
# Out:
#          point  location  snow  year  month  day  hour  con_1h  con_3h  \
# cluster
# 0           44        44    44    44     44   44    44      44      44
# 1           79        79    79    79     79   79    79      79      79
# 2          117       117   117   117    117  117   117     117     117
# 3          305       305   305   305    305  305   305     305     305
# 4          181       181   181   181    181  181   181     181     181
# 5          217       217   217   217    217  217   217     217     217
# 6          215       215   215   215    215  215   215     215     215
# 7          114       114   114   114    114  114   114     114     114
# 8           63        63    63    63     63   63    63      63      63
# 9           21        21    21    21     21   21    21      21      21
#
#          con_6h  pred_cluster  pred_snow_mean  pred_snow_low_int  \
# cluster
# 0            44            44              44                 44
# 1            79            79              79                 79
# 2           117           117             117                117
# 3           305           305             305                305
# 4           181           181             181                181
# 5           217           217             217                217
# 6           215           215             215                215
# 7           114           114             114                114
# 8            63            63              63                 63
# 9            21            21              21                 21
#
#          pred_snow_high_int
# cluster
# 0                        44
# 1                        79
# 2                       117
# 3                       305
# 4                       181
# 5                       217
# 6                       215
# 7                       114
# 8                        63
# 9                        21

# %%
pred_snow_ = []
for i in range(10):
    pred_cluster = [999] * hours
    for n, cl in enumerate(df2_90_test['cluster']):
        p = np.random.rand()
        row = markov_cum[cl]
        for k, r in enumerate(row):
            if p < r:
                pred_cluster.append(k)
                break
    pred_cluster = pred_cluster[:-hours]
    df2_90_test['pred_cluster'] = pred_cluster
    pred_snow = [0] * hours
    for n, cl in enumerate(df2_90_test['pred_cluster'][hours:]):
        a, b, _ = minmax[cl]
        pred_sn = np.random.uniform(a, b, 1)[0]
        pred_snow.append(pred_sn)
    pred_snow_.append(pred_snow)
pred_snow_ = np.array(pred_snow_)
pred_snow_.shape
# Out:
# C:\Users\fembem\AppData\Local\Temp\ipykernel_4072\1435585252.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_90_test['pred_cluster'] = pred_cluster
# (10, 1356)

# %%
mean = np.mean(pred_snow_, axis=0)
mean_95_ci = 2.576 * np.std(pred_snow_, axis=0) / np.sqrt(100)
df2_90_test['pred_snow_mean'] = mean
df2_90_test['pred_snow_low_int'] = mean - mean_95_ci
df2_90_test['pred_snow_high_int'] = mean + mean_95_ci

df2_90_test
# Out:
# C:\Users\fembem\AppData\Local\Temp\ipykernel_4072\2243186725.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_90_test['pred_snow_mean'] = mean
# C:\Users\fembem\AppData\Local\Temp\ipykernel_4072\2243186725.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_90_test['pred_snow_low_int'] = mean - mean_95_ci
# C:\Users\fembem\AppData\Local\Temp\ipykernel_4072\2243186725.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_90_test['pred_snow_high_int'] = mean + mean_95_ci
#       point location  snow  year  month  day  hour  con_1h  con_3h  con_6h  \
# 911      98      동두천   7.0  2018      1    8    20    True    True    True
# 912      98      동두천   7.0  2018      1    8    21    True    True    True
# 913      98      동두천  11.0  2018      1    8    22    True    True    True
# 914      98      동두천  10.0  2018      1    8    23    True    True    True
# 915      98      동두천  10.0  2018      1    9     0    True    True    True
# ...     ...      ...   ...   ...    ...  ...   ...     ...     ...     ...
# 2262     98      동두천   6.0  2022      2    3    17    True    True   False
# 2263     98      동두천   1.0  2022      2    3    18    True    True   False
# 2264     98      동두천   1.0  2022      2    3    19    True   False   False
# 2265     98      동두천   1.0  2022      2    3    20    True   False   False
# 2266     98      동두천   1.0  2022      2    3    21   False   False   False
#
#       cluster  pred_cluster  pred_snow_mean  pred_snow_low_int  \
# 911         3           999        0.000000           0.000000
# 912         3           999        0.000000           0.000000
# 913         3           999        0.000000           0.000000
# 914         3           999        0.000000           0.000000
# 915         3           999        0.000000           0.000000
# ...       ...           ...             ...                ...
# 2262        2             7       20.791688          17.867164
# 2263        0             3       12.737530           9.548040
# 2264        0             6       22.736185          17.502327
# 2265        0             8       29.986803          20.403666
# 2266        0             4       15.923806          14.395639
#
#       pred_snow_high_int
# 911             0.000000
# 912             0.000000
# 913             0.000000
# 914             0.000000
# 915             0.000000
# ...                  ...
# 2262           23.716213
# 2263           15.927020
# 2264           27.970043
# 2265           39.569940
# 2266           17.451973
#
# [1356 rows x 15 columns]

# %%
snow_test = df2_90_test['snow'][(df2_90_test[(df2_90_test['con_6h']==True)].index + hours)[:-hours]]
pred_snow_test = df2_90_test['pred_snow_mean'][(df2_90_test[(df2_90_test['con_6h']==True)].index + hours)[:-hours]]
pred_snow_low_int = df2_90_test['pred_snow_low_int'][(df2_90_test[(df2_90_test['con_6h']==True)].index + hours)[:-hours]]
pred_snow_high_int = df2_90_test['pred_snow_high_int'][(df2_90_test[(df2_90_test['con_6h']==True)].index + hours)[:-hours]]
snow_test.shape
# Out:
# (1189,)

# %%
plt.figure(figsize=(16,8))
# plt.plot(df2_90_test['snow'], 'b.', label='answer')
# plt.plot(df2_90_test['pred_snow'], 'r--', label='pred')
x = range(len(snow_test))
plt.plot(x, snow_test, 'k.', label='answer')
# plt.plot(pred_snow_test, 'r--', label='pred')
# plt.fill_between(x, pred_snow_low_int, pred_snow_high_int)
plt.plot(x, pred_snow_test, 'b-', label='mean')
# plt.plot(x, pred_snow_low_int, 'g--', label='low')
# plt.plot(x, pred_snow_high_int, 'r--', label='high')

plt.legend()

# %%
plt.figure(figsize=(8,8))
plt.scatter(snow_test, pred_snow_test)
plt.xlabel('Answer')
plt.ylabel("Prediction")
plt.plot([0, np.max(snow_test)], [0, np.max(snow_test)], 'r-')

# %%
np.sqrt(np.sum((snow_test - pred_snow_test) ** 2) / np.sum((pred_snow_test) ** 2))
# Out:
# 0.5116466843979115

# %%
np.sqrt(np.sum((snow_test - pred_snow_test) ** 2) / len(pred_snow_test))
# Out:
# 16.54422456911471

# %%
np.unique(np.array(df2_90_test['cluster'] == df2_90_test['pred_cluster']), return_counts=True)
# Out:
# (array([False,  True]), array([834, 344], dtype=int64))
